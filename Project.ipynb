# %%
from tkinter import*
root = Tk()
root.title("Registration form")
root.geometry("900x1000")


he = Label(root , text= "Welcome to Radient classes" ,font= "bold_font",fg= "red",pady= 20,padx=10).grid(row=0,column=4)


name = Label(root, text="Enter Your Name*", width=10,pady=20 ,padx=20)
middle =Label(root, text="Enter middle Name*", pady =20,padx=20)
last = Label(root, text="Enter Your Last Name*",pady=20,padx=30)
phone = Label(root, text="Enter phone number*",pady=20,padx=20)
dob = Label(root, text="Date of Birth",pady=20,padx=30)
gender = Label(root, text="Enter Your Gender*",pady=20,padx=30)
male = Radiobutton(root, text="Male", value=1,pady=20, padx=10)
female= Radiobutton(root, text="Female", value=2,pady=20,padx=10)
email= Label(root, text="Enter Your mail*",pady=20,padx=20)
street = Label(root, text="Enter Stress Adress" ,pady=20,padx=20)
pin =Label(root,text="Pin code",pady=20,padx=40)
education = Label(root, text="Education Qualification*",pady=20,padx=20)
stream = Label(root, text = "Stream*",pady=20,padx=40)
university= Label(root, text="Enter University Name*",pady=20,padx=20)
marks= Label(root,text="Marks in Percentage*",pady=20,padx=20)
experiance=Checkbutton(root,text="You have any Experience",pady=20,padx=20)
company=Label(root,text="Comapny Name",pady=20,padx=20)
# submit = Button(root,text="Submit",pady=40,padx=40)
submit=Button(text="Submit",fg="blue", bg = "white" , pady=10 , padx=20).grid(row=12,column=2)




name.grid(row=1, column=2)
middle.grid(row=1, column =4)
last.grid(row=2, column=2)
phone.grid(row=3, column=2)
dob.grid(row=3, column=4)
gender.grid(row=4, column=2)
male.grid(row=4, column=3)
female.grid(row=5, column=3)
email.grid(row=4, column=4)
street.grid(row=7,column=2)
pin.grid(row=7,column = 4)
education.grid(row=8, column=2)
stream.grid(row=8, column=4)
university.grid(row=10, column=2)
marks.grid(row=10, column=4)
experiance.grid(row=11,column=3)
company.grid(row=11,column=4)




namevalue = StringVar()
middlevalue = StringVar()
lastvalue = StringVar()
phonevalue = StringVar()
dobvalue = StringVar()
gendervalue = StringVar()
malevalue = StringVar()
femalevalue = StringVar()
emailvalue = StringVar()
streetvalue = StringVar()
pinvalue = StringVar()
educationvalue = StringVar()
streamvalue = StringVar()
universityvalue = StringVar()
marksvalue = StringVar()
experiancevalue = StringVar()
companyvalue = StringVar()
submitvalue = StringVar()



nameentry = Entry(root, textvariable=namevalue)
middleentry = Entry(root, textvariable= middlevalue)
lastentry = Entry(root, textvariable=lastvalue)
phoneentry = Entry(root, textvariable=phonevalue)
dobentry = Entry(root, textvariable=dobvalue)
emailentry = Entry(root, textvariable=emailvalue)
streetentry = Entry(root, textvariable=streetvalue)
pinentry = Entry(root, textvariable=pinvalue)
educationentry = Entry(root, textvariable=educationvalue)
streamentry = Entry(root, textvariable=streamvalue)
universityentry = Entry(root, textvariable=universityvalue)
marksentry = Entry(root, textvariable=marksvalue)
companyentry = Entry(root, textvariable=companyvalue )


nameentry.grid(row=1, column =3)
middleentry.grid(row=1, column =5)
lastentry.grid(row=2, column =3)
phoneentry.grid(row=3, column = 3)
dobentry.grid(row=3, column =5)
emailentry.grid(row=4, column =5)
streetentry.grid(row=7,column=3)
pinentry.grid(row=7,column=5)
educationentry.grid(row=8, column =3)
streamentry.grid(row=8, column=5)
universityentry.grid(row=10, column =3)
marksentry.grid(row=10, column =5)
companyentry.grid(row=11, column= 5)



mainloop()
